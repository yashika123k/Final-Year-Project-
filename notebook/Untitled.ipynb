# %%
import pandas as  pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ["id","pos_x","pos_y","dist_sink","is_ch","energy","neighbours","t_range","reward"]
df = pd.read_csv("../rust-sim/src/data.csv",names=columns)

# %%
df
# Out:
#        id       pos_x       pos_y   dist_sink  is_ch    energy  neighbours  \
# 0       0  295.393460  416.761400  172.829210   True  1.993840           1
# 1       1   89.390040  490.487580  289.188230  False  1.999700           2
# 2       2   40.141403  499.554440  326.064480   True  1.939262           0
# 3       3  193.674030  394.333300  154.934570   True  1.994164           0
# 4       4  299.510530  298.305020   69.171295  False  1.999474           1
# ...    ..         ...         ...         ...    ...       ...         ...
# 23160  89   93.399050  414.913800  227.421220  False  0.262254           0
# 23161  91  142.665740   61.733723  216.713710  False  0.140514           0
# 23162  93   70.039510  190.727770  189.470250  False  0.845096           1
# 23163  96  180.938540  289.844570   79.731270  False  1.364216           0
# 23164  97   65.242170  140.219150  214.912280  False  0.476181           1
#
#          t_range    reward
# 0      26.019634 -0.006160
# ...

# %%
sns.barplot(x=df["is_ch"] , y=df["energy"])
# Out:
# <Axes: xlabel='is_ch', ylabel='energy'>

# %%
sns.barplot(x=df["neighbours"] , y=df["reward"],hue=df["is_ch"])
# Out:
# <Axes: xlabel='neighbours', ylabel='reward'>
